# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (2.8.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (3.6.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in c:\users\mahakathir\anaconda3\envs\mahakathit\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as ms

# %%
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
graph_mark=ms.DiGraph(detail="mark's detials")

# %%
graph_mark.add_node("mark",pos=(0,0))
graph_mark.add_node("cat",pos=(-2,6))
graph_mark.add_node("student",pos=(2,-5))
graph_mark.add_node("animal",pos=(1,6))
graph_mark.add_node("california",pos=(4,6))
graph_mark.add_node("spinoff",pos=(-5,-5))
graph_mark.add_node("soccer",pos=(-5,2))
graph_mark.add_node("sports club",pos=(0,-8))
graph_mark.add_node("csu",pos=(5,-1))
pos=ms.get_node_attributes(graph_mark,"pos")

# %%
graph_mark.add_edge("mark","cat",weight="has a")
graph_mark.add_edge("mark","student",weight="is a")
graph_mark.add_edge("cat","animal",weight="is a")
graph_mark.add_edge("mark","soccer",weight="player")
graph_mark.add_edge("mark","spinoff",weight="is a part of")
graph_mark.add_edge("mark","california",weight="lives in")
graph_mark.add_edge("mark","animal",weight="lover")
graph_mark.add_edge("student","csu",weight="in")
graph_mark.add_edge("spinoff","sports club",weight="is a")
graph_mark.add_edge("csu","california",weight="is in")
weight=ms.get_edge_attributes(graph_mark,"weight")

# %%
plt.figure()
ms.draw_networkx(graph_mark,pos,font_weight="bold",node_size=2000,font_size=7)
ms.draw_networkx_edge_labels(graph_mark,pos,edge_labels=weight)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {('mark', 'cat'): Text(-1.0, 3.0, 'has a'),
#  ('mark', 'student'): Text(1.0, -2.5, 'is a'),
#  ('mark', 'soccer'): Text(-2.5, 1.0, 'player'),
#  ('mark', 'spinoff'): Text(-2.5, -2.5, 'is a part of'),
#  ('mark', 'california'): Text(2.0, 3.0, 'lives in'),
#  ('mark', 'animal'): Text(0.5, 3.0, 'lover'),
#  ('cat', 'animal'): Text(-0.5, 6.0, 'is a'),
#  ('student', 'csu'): Text(3.5, -3.0, 'in'),
#  ('spinoff', 'sports club'): Text(-2.5, -6.5, 'is a'),
#  ('csu', 'california'): Text(4.5, 2.5, 'is in')}
